# %%
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir('drive/My Drive/Colab Notebooks/EECS595/final_proj')
# !ls
# Out:
# Mounted at /content/drive
# emoji_bert_sentiment_analysis.ipynb  res
# emotag-dimension-as-emojis.txt	     Untitled0.ipynb
# logs4				     vanilla_bert_sentiment_analysis.ipynb
# rehydrated_tweets_parquet

# %%
import pandas as pd
from transformers import BertTokenizerFast, BertModel, Trainer, TrainingArguments
import torch
from torch.utils.data import Dataset
from torch import nn
import emoji as emo
from tqdm import tqdm
import concurrent.futures
import multiprocessing as mp
import time
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from collections import Counter
import unicodedata as ud
from transformers import AutoModelForSequenceClassification, AutoTokenizer
from itertools import repeat
import numpy as np
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

# %%
SEED = 595

# %% [markdown]
# # 1. Load Data

# %%
parquet_dir = './rehydrated_tweets_parquet'

# %% [markdown]
# Get the paths of all parquet files

# %%
parquet_list = []
for root, _, files in os.walk(parquet_dir):
    for file in files:
        if file[0] != '.':
            parquet_file_path = os.path.join(root, file)
            if parquet_file_path[-8:] == '.parquet':
                parquet_list.append(parquet_file_path)

# %% [markdown]
# ### Subset Data
# We subset data temporarily just for testing and initial temporary results

# %%
# just use the first 2 parquet files
parquet_list = parquet_list[:2]

# %% [markdown]
# Load subset and apply basic pre-processing

# %%
df = pd.concat(map(pd.read_parquet, tqdm(parquet_list)))
df = df.reset_index()
df = df.set_index('index')
# Out:
# 100%|██████████| 2/2 [00:03<00:00,  1.76s/it]

# %%
df
# Out:
#       tweet_date             tweet_id  sentiment emojis  tweet_day  \
# index
# 0     2019-04-08  1115139461875097600          1      😘          8
# 1     2019-04-08  1115139461875097600          1      😘          8
# 2     2019-04-08  1115139461912731648          1      🤗          8
# 5     2019-04-08  1115139512231792640          1      😆          8
# 6     2019-04-08  1115139516438724608          1      😍          8
# ...          ...                  ...        ...    ...        ...
# 33970 2019-04-22  1120567851780378624          0  :(,:(         22
# 33971 2019-04-22  1120567855978811392          1      😝         22
# 33973 2019-04-22  1120567885305245696          1      😘         22
# 33974 2019-04-22  1120567902095249408          0      😬         22
# 33975 2019-04-22  1120567923066724352          1      👍         22
#
#        tweet_month  tweet_year tweet_year_month  \
# index
# 0                4        2019          2019-04
# 1                4        2019          2019-04
# 2                4        2019          2019-04
# 5                4        2019          2019-04
# 6                4        2019          2019-04
# ...            ...         ...              ...
# 33970            4        2019          2019-04
# 33971            4        2019          2019-04
# 33973            4        2019          2019-04
# 33974            4        2019          2019-04
# 33975            4        2019          2019-04
#
#                                               tweet_text
# index
# 0      RT @tpagon: ระดับเดซิเบลของเสียงต่างๆ https://...
# 1        GOT7 fighting😘😘😘\n#GOT7 \n#BBMAs\n@GOT7Official
# 2      I love it when ppl come to me to help with dog...
# 5                        Aaaw you're a hella sweet bros😆
# 6                                           That booty😍😍
# ...                                                  ...
# 33970                         @Psycopathhh_ noted ate :(
# 33971             Craving something sweet, like donuts😝😝
# 33973                        @paraadonat Miss you too 😘😂
# 33974                   shidd mike b never even had one😬
# 33975  @issuingz @methodvendorsss @HakimiKimie12 @DDB...
#
# [30311 rows x 9 columns]

# %% [markdown]
# # 2. Split into train and test sets

# %%
train_df, test_df = train_test_split(df, test_size = 0.2, random_state = SEED)

# %%
train_df
# Out:
#       tweet_date             tweet_id  sentiment emojis  tweet_day  \
# index
# 4086  2019-04-22  1120278935525150720          0    😭,😭         22
# 13895 2019-04-08  1115434778654859264          0      😞          8
# 8045  2019-04-22  1120323957163548672          0      😩         22
# 27610 2019-04-22  1120500289902120960          0      🙃         22
# 17083 2019-04-08  1115470434420396032          1    😌,😌          8
# ...          ...                  ...        ...    ...        ...
# 15400 2019-04-08  1115450884782161920          1      😍          8
# 22619 2019-04-22  1120449773738315776          0      😬         22
# 22103 2019-04-22  1120444555986386944          0      😫         22
# 11629 2019-04-08  1115409898043576320          1    😌,😌          8
# 2839  2019-04-08  1115192675022581760          1      😍          8
#
#        tweet_month  tweet_year tweet_year_month  \
# index
# 4086             4        2019          2019-04
# 13895            4        2019          2019-04
# 8045             4        2019          2019-04
# 27610            4        2019          2019-04
# 17083            4        2019          2019-04
# ...            ...         ...              ...
# 15400            4        2019          2019-04
# 22619            4        2019          2019-04
# 22103            4        2019          2019-04
# 11629            4        2019          2019-04
# 2839             4        2019          2019-04
#
#                                               tweet_text
# index
# 4086                       @jeonierals FCK PIPAY. FCK! 😭
# 13895                        Those late night thoughts 😞
# 8045   “EVERYBODY AIN’T PROUD OF U🎯\nThey just surpri...
# 27610  @stefanypackk @SsssamanthaaMUA I just started ...
# 17083                            so help me, help you 😌🤝
# ...                                                  ...
# 15400                         @podgie_TV oh my goodness😍
# 22619  RT @LaQuica91: aretter de faire sortir votre c...
# 22103      @chandlerrkentt_ My baby 😫😫😫😫 fuck I love him
# 11629                           All I can do is smile 😌😌
# 2839   This little corner of Paris is oh so dreamy😍. ...
#
# [24248 rows x 9 columns]

# %% [markdown]
# # 4. Get unique emoticons in train `emojis` column
# (We don't have a way of finding emoticons in the text)

# %%
emoticons = set()
for emoji_str in train_df['emojis'].values:
    if ',' in emoji_str:
        emoji_list = emoji_str.split(',')
        for emoji in emoji_list:
            if not emo.is_emoji(emoji):
                emoticons.add(emoji)
    else:
        if not emo.is_emoji(emoji_str):
            emoticons.add(emoji_str)
emoticons = list(emoticons)

# %%
emoticons[:5]
# Out:
# [':-)', ';^)', ': (', 'D;', 'xD']

# %% [markdown]
# # 5. Remove emojis from text

# %%
train_df['demojized_tweet_text'] = train_df['tweet_text'].apply(emo.replace_emoji)
test_df['demojized_tweet_text'] = test_df['tweet_text'].apply(emo.replace_emoji)

# %%
train_df.head(3)
# Out:
#       tweet_date             tweet_id  sentiment emojis  tweet_day  \
# index
# 4086  2019-04-22  1120278935525150720          0    😭,😭         22
# 13895 2019-04-08  1115434778654859264          0      😞          8
# 8045  2019-04-22  1120323957163548672          0      😩         22
#
#        tweet_month  tweet_year tweet_year_month  \
# index
# 4086             4        2019          2019-04
# 13895            4        2019          2019-04
# 8045             4        2019          2019-04
#
#                                               tweet_text  \
# index
# 4086                       @jeonierals FCK PIPAY. FCK! 😭
# 13895                        Those late night thoughts 😞
# 8045   “EVERYBODY AIN’T PROUD OF U🎯\nThey just surpri...
#
#                                     demojized_tweet_text
# index
# 4086                        @jeonierals FCK PIPAY. FCK!
# 13895                         Those late night thoughts
# 8045   “EVERYBODY AIN’T PROUD OF U\nThey just surpris...

# %% [markdown]
# # 6. Create a dict for emoticons and apply a similar "demojize" operation in same fashion as 5.

# %%
replace_w_empty = [''] * len(emoticons)
emoticon_dict = dict(zip(emoticons, replace_w_empty))

# %%
dict(list(emoticon_dict.items())[:5])
# Out:
# {':-)': '', ';^)': '', ': (': '', 'D;': '', 'xD': ''}

# %%
def replace_emoticon_with_name(tweet, emoticon_dict):
    for key in emoticon_dict:
        tweet = tweet.replace(key, emoticon_dict[key])
    return tweet

# %%
train_df['demojized_tweet_text'] = train_df['demojized_tweet_text'].apply(replace_emoticon_with_name, emoticon_dict=emoticon_dict)
test_df['demojized_tweet_text'] = test_df['demojized_tweet_text'].apply(replace_emoticon_with_name, emoticon_dict=emoticon_dict)

# %%
train_df.head(3)
# Out:
#       tweet_date             tweet_id  sentiment emojis  tweet_day  \
# index
# 4086  2019-04-22  1120278935525150720          0    😭,😭         22
# 13895 2019-04-08  1115434778654859264          0      😞          8
# 8045  2019-04-22  1120323957163548672          0      😩         22
#
#        tweet_month  tweet_year tweet_year_month  \
# index
# 4086             4        2019          2019-04
# 13895            4        2019          2019-04
# 8045             4        2019          2019-04
#
#                                               tweet_text  \
# index
# 4086                       @jeonierals FCK PIPAY. FCK! 😭
# 13895                        Those late night thoughts 😞
# 8045   “EVERYBODY AIN’T PROUD OF U🎯\nThey just surpri...
#
#                                     demojized_tweet_text
# index
# 4086                        @jeonierals FCK PIPAY. FCK!
# 13895                         Those late night thoughts
# 8045   “EVERYBODY AIN’T PROUD OF U\nThey just surpris...

# %% [markdown]
# # 7. Perform Sentiment Analysis

# %%
model = "bert-base-cased"
tokenizer = AutoTokenizer.from_pretrained(model, use_fast = True)
model = AutoModelForSequenceClassification.from_pretrained(model)
# Out:
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/436k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
model = model.to(device)

# %%
train_texts = train_df['demojized_tweet_text'].values.tolist()
train_labels = train_df['sentiment'].values.tolist()
test_texts = test_df['demojized_tweet_text'].values.tolist()
test_labels = test_df['sentiment'].values.tolist()

# %%
train_encodings = tokenizer(train_texts, truncation=True, padding=True, return_tensors='pt').to(device)
test_encodings = tokenizer(test_texts, truncation=True, padding=True, return_tensors='pt').to(device)

# %%
class SentimentDataset(Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item
    
    def __len__(self):
        return len(self.labels)

# %%
train_dataset = SentimentDataset(train_encodings, train_labels)
test_dataset = SentimentDataset(test_encodings, test_labels)

# %%
def compute_metrics(p):
    pred, labels = p
    pred = np.argmax(pred, axis = 1)
    
    accuracy = accuracy_score(y_true = labels, y_pred = pred)
    recall = recall_score(y_true=labels, y_pred=pred)
    precision = precision_score(y_true=labels, y_pred=pred)
    f1 = f1_score(labels, pred, average='weighted')

    return {"accuracy": accuracy,"recall": recall, "precision": precision,"f1_score":f1}

# %%
training_args = TrainingArguments(
    output_dir='./res_vanil',          # output directory
    evaluation_strategy="steps",
    num_train_epochs=5,              # total number of training epochs
    per_device_train_batch_size=32,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir='./logs4_vanil',            # directory for storing logs
    load_best_model_at_end=True,
    dataloader_pin_memory=False
)

# %%
trainer = Trainer(
    model = model,
    args = training_args,
    train_dataset = train_dataset,
    eval_dataset = test_dataset,
    compute_metrics = compute_metrics
)
trainer.train()
# Out:
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 24248
#   Num Epochs = 5
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 3790
#   Number of trainable parameters = 108311810
# <ipython-input-25-59abc277c9d1>:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
#     <div>
#
#       <progress value='3790' max='3790' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3790/3790 49:32, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Recall</th>
#       <th>Precision</th>
#       <th>F1 Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.621900</td>
#       <td>0.573078</td>
#       <td>0.682335</td>
#       <td>0.577145</td>
#       <td>0.748754</td>
#       <td>0.679025</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.534100</td>
#       <td>0.595845</td>
#       <td>0.692726</td>
#       <td>0.806658</td>
#       <td>0.666843</td>
#       <td>0.688037</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.497600</td>
#       <td>0.571427</td>
#       <td>0.698169</td>
#       <td>0.738156</td>
#       <td>0.694997</td>
#       <td>0.697563</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.327200</td>
#       <td>0.771547</td>
#       <td>0.692726</td>
#       <td>0.677017</td>
#       <td>0.712361</td>
#       <td>0.692765</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.266800</td>
#       <td>1.052030</td>
#       <td>0.686294</td>
#       <td>0.769206</td>
#       <td>0.670480</td>
#       <td>0.683733</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.174500</td>
#       <td>1.124344</td>
#       <td>0.682171</td>
#       <td>0.689181</td>
#       <td>0.692506</td>
#       <td>0.682193</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.117100</td>
#       <td>1.453490</td>
#       <td>0.689263</td>
#       <td>0.672855</td>
#       <td>0.709177</td>
#       <td>0.689297</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 6063
#   Batch size = 64
# Saving model checkpoint to ./res_vanil/checkpoint-500
# Configuration saved in ./res_vanil/checkpoint-500/config.json
# Model weights saved in ./res_vanil/checkpoint-500/pytorch_model.bin
# <ipython-input-25-59abc277c9d1>:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 6063
#   Batch size = 64
# Saving model checkpoint to ./res_vanil/checkpoint-1000
# Configuration saved in ./res_vanil/checkpoint-1000/config.json
# Model weights saved in ./res_vanil/checkpoint-1000/pytorch_model.bin
# <ipython-input-25-59abc277c9d1>:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 6063
#   Batch size = 64
# Saving model checkpoint to ./res_vanil/checkpoint-1500
# Configuration saved in ./res_vanil/checkpoint-1500/config.json
# Model weights saved in ./res_vanil/checkpoint-1500/pytorch_model.bin
# <ipython-input-25-59abc277c9d1>:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 6063
#   Batch size = 64
# Saving model checkpoint to ./res_vanil/checkpoint-2000
# Configuration saved in ./res_vanil/checkpoint-2000/config.json
# Model weights saved in ./res_vanil/checkpoint-2000/pytorch_model.bin
# <ipython-input-25-59abc277c9d1>:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 6063
#   Batch size = 64
# Saving model checkpoint to ./res_vanil/checkpoint-2500
# Configuration saved in ./res_vanil/checkpoint-2500/config.json
# Model weights saved in ./res_vanil/checkpoint-2500/pytorch_model.bin
# <ipython-input-25-59abc277c9d1>:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 6063
#   Batch size = 64
# Saving model checkpoint to ./res_vanil/checkpoint-3000
# Configuration saved in ./res_vanil/checkpoint-3000/config.json
# Model weights saved in ./res_vanil/checkpoint-3000/pytorch_model.bin
# <ipython-input-25-59abc277c9d1>:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 6063
#   Batch size = 64
# Saving model checkpoint to ./res_vanil/checkpoint-3500
# Configuration saved in ./res_vanil/checkpoint-3500/config.json
# Model weights saved in ./res_vanil/checkpoint-3500/pytorch_model.bin
# <ipython-input-25-59abc277c9d1>:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./res_vanil/checkpoint-1500 (score: 0.5714267492294312).
# TrainOutput(global_step=3790, training_loss=0.34337450696799243, metrics={'train_runtime': 2975.7147, 'train_samples_per_second': 40.743, 'train_steps_per_second': 1.274, 'total_flos': 8099503839336000.0, 'train_loss': 0.34337450696799243, 'epoch': 5.0})

# %%
trainer.evaluate()
# Out:
# ***** Running Evaluation *****
#   Num examples = 6063
#   Batch size = 64
# <ipython-input-25-59abc277c9d1>:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
#     <div>
#
#       <progress value='95' max='95' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [95/95 00:40]
#     </div>
# {'eval_loss': 0.5714267492294312,
#  'eval_accuracy': 0.698169223156853,
#  'eval_recall': 0.7381562099871959,
#  'eval_precision': 0.6949969861362266,
#  'eval_f1_score': 0.6975631435494667,
#  'eval_runtime': 41.3608,
#  'eval_samples_per_second': 146.588,
#  'eval_steps_per_second': 2.297,
#  'epoch': 5.0}
